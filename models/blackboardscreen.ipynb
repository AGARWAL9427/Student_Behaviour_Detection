# %%
import zipfile
import os

# Define paths
zip_path = "/content/drive/MyDrive/SCB-Dataset/5k_HRW_yolo_Dataset_jpg.zip"  # Update with your actual zip file path
extract_path = "/content/drive/MyDrive/dataset"  # Where the dataset will be extracted

# Unzip the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset unzipped successfully!")
# Out:
# ✅ Dataset unzipped successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#from ultralytics import YOLO
import shutil

# Define a path in Google Drive to save results
#drive_path = "/content/drive/MyDrive/models"

# Ensure the directory exists
#import os
#os.makedirs(drive_path, exist_ok=True)

# Function to train & save each model
def train_and_save(data_yaml, model_name):
    model = YOLO("yolo11n.yaml").load("yolo11n.pt")
    model.train(data=data_yaml, epochs=4, imgsz=640)

    metrics = model.val()
# Extract and print accuracy-related metrics
    print(f"🔹 mAP@50: {metrics.box.map():.3f}")  # mAP at IoU 0.5
    print(f"🔹 mAP@50: {metrics.map50():.3f}")  # Mean AP at IoU 0.5
    print(f"🔹 Precision: {metrics.mp():.3f}")  # Mean precision of all classes
    print(f"🔹 Recall: {metrics.mr():.3f}")  # Mean recall of all classes# Move training results to Google Drive
    shutil.move("/content/runs", f"{drive_path}/{model_name}")

# Train on each category & save results
train_and_save("/content/drive/MyDrive/dataset/SCB5-BlackBoard-Sreen--2024-9-17/dataset.yaml", "BlackBoardScreen Model")

# %%
from ultralytics import YOLO
import shutil

# Define a path in Google Drive to save results
drive_path = "/content/drive/MyDrive/models"

# Ensure the directory exists
import os
os.makedirs(drive_path, exist_ok=True)

# Function to train & save each model
def train_and_save(data_yaml, model_name):
    model = YOLO("yolo11n.yaml").load("yolo11n.pt")
    model.train(data=data_yaml, epochs=1, imgsz=640)

    shutil.move("/content/runs", f"{drive_path}/{model_name}")

# Train on each category & save results
train_and_save("/content/drive/MyDrive/dataset/SCB5-BlackBoard-Sreen-Teacher-2024-10-15/dataset.yaml", "BlackBoardScreenTeacher Model")
# Out:
# Transferred 499/499 items from pretrained weights
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...
